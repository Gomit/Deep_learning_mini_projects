# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(
        batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (
        num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.532640
# Nearest to seven: inoculation, midline, carboxylic, recumbent, saffron, settles, amides, reconsideration,
# Nearest to history: raising, manifestation, seer, vulpes, sloppy, hainan, ap, seifert,
# Nearest to united: infatuated, voiced, undifferentiated, heme, alkanes, exceptionally, reversing, yggdrasil,
# Nearest to been: midnight, homestead, victory, erupt, faint, hasan, devoured, overviews,
# Nearest to and: appoint, inquiry, dues, trial, bartlett, alphege, dynamic, eritreans,
# Nearest to or: manifesting, cosgrave, mond, cameroon, proposition, hitomaro, macromedia, clerics,
# Nearest to may: striving, replenished, supercomputers, effortless, hiv, molasses, pederasty, stinging,
# Nearest to has: fold, quark, kohanim, lps, skip, intervention, copts, lullaby,
# Nearest to s: revolved, phagocytosis, shaun, dropouts, intervening, doctorates, norden, martial,
# Nearest to d: knicks, hillbilly, omnium, supergirl, helaman, sheds, rao, randori,
# Nearest to state: protagoras, panzer, zach, cycles, derided, galerie, octagonal, portfolios,
# Nearest to new: possessors, phosphors, aberdeen, grit, helsing, capri, fuels, challengers,
# Nearest to there: federico, ttingen, objects, unrelated, brigham, rebuttal, asymptomatic, experiencing,
# Nearest to after: knowingly, poor, expansionary, louisville, alamein, coral, ave, anemia,
# Nearest to b: geoffroy, fractals, tapped, jt, parable, mithraism, misspelling, penance,
# Nearest to UNK: waterborne, ionian, leopoldo, downloaded, helsingborg, chadwick, dte, tech,
# Average loss at step 2000: 4.374148
# Average loss at step 4000: 3.859622
# Average loss at step 6000: 3.788310
# Average loss at step 8000: 3.685107
# Average loss at step 10000: 3.615197
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to history: manifestation, number, bauds, ap, vulpes, certain, sloppy, land,
# Nearest to united: reversing, voiced, stanislavski, outing, bletchley, misogyny, infatuated, alkanes,
# Nearest to been: jm, butterfly, vespucci, be, arise, faint, victory, calamities,
# Nearest to and: or, american, he, who, cupid, navies, for, like,
# Nearest to or: and, for, halakha, s, than, apostle, juno, ok,
# Nearest to may: can, would, duration, cleaned, subsistence, pederasty, chickasaw, stab,
# Nearest to has: had, was, is, have, became, interplay, opec, cabo,
# Nearest to s: his, shem, terry, schwenkfeld, intervening, interstates, or, and,
# Nearest to d: lica, hillbilly, entrance, knicks, omnium, commercialism, melanoleuca, b,
# Nearest to state: zach, protagoras, painted, panzer, shaivism, sinners, portfolios, accessibility,
# Nearest to new: possessors, second, punished, reintroduce, sense, lands, phosphors, neurotransmitter,
# Nearest to there: it, lifeform, not, no, he, asymptomatic, spock, cascade,
# Nearest to after: under, knowingly, expansionary, kushner, before, poor, during, appearances,
# Nearest to b: geoffroy, countess, mithraism, penance, rorty, fractals, tapped, extradited,
# Nearest to UNK: fas, egoist, ingestion, guess, pathogens, demarco, extremely, agrees,
# Average loss at step 12000: 3.603686
# Average loss at step 14000: 3.570090
# Average loss at step 16000: 3.409614
# Average loss at step 18000: 3.458216
# Average loss at step 20000: 3.535356
# Nearest to seven: eight, six, five, three, nine, four, zero, two,
# Nearest to history: manifestation, vulpes, number, griff, bauds, names, period, latinos,
# Nearest to united: reversing, voiced, stanislavski, bletchley, same, first, outing, flagg,
# Nearest to been: be, become, were, was, by, przewodnicz, butterfly, arise,
# Nearest to and: or, american, in, complains, for, but, charming, at,
# Nearest to or: and, than, bute, with, products, laird, skiego, gander,
# Nearest to may: can, would, could, will, must, cleaned, should, stab,
# Nearest to has: had, was, have, is, became, interplay, receptor, since,
# Nearest to s: lavish, dooley, martial, national, terry, scramble, schwenkfeld, auguste,
# Nearest to d: b, bioinformatics, bootleg, fliers, de, arresting, probable, lag,
# Nearest to state: protagoras, painted, zach, sinners, bryozoa, unintentional, facsimile, crossed,
# Nearest to new: punished, second, reintroduce, lands, capri, possessors, buckyballs, gotland,
# Nearest to there: it, no, they, which, he, astray, often, but,
# Nearest to after: before, under, kushner, when, knowingly, during, millimeters, synchronized,
# Nearest to b: d, mithraism, geoffroy, countess, detriment, steinberg, bioinformatics, agrarianism,
# Nearest to UNK: accented, l, dysphoria, iau, obelix, vicious, nimh, btr,
# Average loss at step 22000: 3.503469
# Average loss at step 24000: 3.490000
# Average loss at step 26000: 3.478499
# Average loss at step 28000: 3.480895
# Average loss at step 30000: 3.503163
# Nearest to seven: eight, four, five, six, nine, three, zero, two,
# Nearest to history: period, griff, range, bauds, names, latinos, anteater, number,
# Nearest to united: reversing, voiced, bletchley, stanislavski, infatuated, outing, same, kingman,
# Nearest to been: become, be, was, were, leds, already, przewodnicz, arise,
# Nearest to and: or, in, s, who, but, american, of, ios,
# Nearest to or: and, monophysite, than, leaderships, as, instant, luncheon, skiego,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to has: had, have, is, was, since, gur, bloomfield, statesmen,
# Nearest to s: his, and, coronations, sudden, chanter, en, proclaiming, her,
# Nearest to d: b, bioinformatics, fujiwara, bootleg, stateless, fliers, lica, august,
# Nearest to state: states, painted, protagoras, sinners, uses, government, crossed, zach,
# Nearest to new: punished, second, buckyballs, particular, gotland, bisexual, vol, astronomical,
# Nearest to there: they, it, he, no, often, which, still, viruses,
# Nearest to after: before, during, when, under, for, ascii, synchronized, from,
# Nearest to b: d, mithraism, geoffroy, detriment, steinberg, diminished, rorty, conti,
# Nearest to UNK: accented, agrees, paul, gasification, persons, termination, czes, exporters,
# Average loss at step 32000: 3.499576
# Average loss at step 34000: 3.494326
# Average loss at step 36000: 3.454507
# Average loss at step 38000: 3.307437
# Average loss at step 40000: 3.431188
# Nearest to seven: eight, six, five, nine, four, three, one, zero,
# Nearest to history: period, list, griff, range, names, anteater, bauds, collection,
# Nearest to united: bletchley, reversing, voiced, stanislavski, kingman, catamarans, outing, infatuated,
# Nearest to been: become, be, was, were, leds, already, recently, never,
# Nearest to and: or, but, including, vicki, platonist, goats, while, with,
# Nearest to or: and, than, a, skiego, pitched, mackey, elegiac, vicki,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to has: had, have, was, is, hydrodynamic, since, gur, booting,
# Nearest to s: his, coronations, scramble, rx, amram, stewart, compactness, fula,
# Nearest to d: b, fujiwara, UNK, bioinformatics, fliers, o, c, bootleg,
# Nearest to state: government, states, shipwrecked, protagoras, wang, sinners, facsimile, crossed,
# Nearest to new: punished, carboxylic, gotland, second, grinnell, buckyballs, lawrencium, bisexual,
# Nearest to there: it, they, he, still, usually, often, she, now,
# Nearest to after: before, during, when, for, saw, ascii, despite, jains,
# Nearest to b: d, UNK, w, nm, geoffroy, gang, leiber, v,
# Nearest to UNK: b, d, balloon, l, australasia, corn, dutch, leiber,
# Average loss at step 42000: 3.434037
# Average loss at step 44000: 3.455637
# Average loss at step 46000: 3.449159
# Average loss at step 48000: 3.359314
# Average loss at step 50000: 3.382488
# Nearest to seven: eight, six, nine, four, three, five, zero, two,
# Nearest to history: period, list, bunyan, anteater, griff, capable, wanton, bauds,
# Nearest to united: bletchley, reversing, voiced, stanislavski, kingman, catamarans, southern, beneath,
# Nearest to been: become, be, were, was, recently, already, leds, arise,
# Nearest to and: or, but, while, of, enabling, including, s, under,
# Nearest to or: and, than, but, while, leaderships, elegiac, seasonal, docile,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to has: had, have, was, is, hydrodynamic, booting, gur, since,
# Nearest to s: whose, sternum, his, jonson, and, subordinates, her, schwenkfeld,
# Nearest to d: b, fujiwara, e, c, o, f, fliers, simple,
# Nearest to state: government, states, shipwrecked, wang, protagoras, crossed, atrocities, bryozoa,
# Nearest to new: punished, local, quench, particular, remarque, lawrencium, second, beauharnais,
# Nearest to there: it, they, he, still, she, now, often, twelfth,
# Nearest to after: before, when, during, while, since, saw, however, americanization,
# Nearest to b: d, nm, w, h, evasive, gang, f, exploitative,
# Nearest to UNK: iter, ncsa, agrees, et, vernet, horatio, usurper, volleys,
# Average loss at step 52000: 3.436458
# Average loss at step 54000: 3.425034
# Average loss at step 56000: 3.440570
# Average loss at step 58000: 3.399016
# Average loss at step 60000: 3.392273
# Nearest to seven: eight, four, nine, six, five, three, zero, one,
# Nearest to history: geography, list, demographics, period, myst, jars, culture, status,
# Nearest to united: bletchley, stanislavski, kingman, catamarans, beneath, reversing, southern, voiced,
# Nearest to been: become, be, recently, were, was, leds, already, had,
# Nearest to and: or, but, than, including, like, aquarium, further, enabling,
# Nearest to or: and, than, leaderships, pygmies, mand, waid, golfer, vicki,
# Nearest to may: can, would, will, must, could, should, might, cannot,
# Nearest to has: had, have, is, was, bacterial, gur, having, hydrodynamic,
# Nearest to s: whose, coronations, sternum, sheen, deianira, his, grilled, my,
# Nearest to d: b, c, w, fujiwara, f, r, leiber, august,
# Nearest to state: government, city, shipwrecked, wang, states, protagoras, bryozoa, berkeley,
# Nearest to new: lawrencium, grinnell, particular, second, prokaryotic, remarque, newtonian, quench,
# Nearest to there: they, it, he, she, still, now, this, often,
# Nearest to after: before, during, when, saw, while, despite, under, since,
# Nearest to b: d, c, f, nm, h, m, n, w,
# Nearest to UNK: termination, munda, mezzo, andes, dissociate, runnymede, missionaries, paco,
# Average loss at step 62000: 3.239644
# Average loss at step 64000: 3.258885
# Average loss at step 66000: 3.402747
# Average loss at step 68000: 3.399668
# Average loss at step 70000: 3.360153
# Nearest to seven: six, four, eight, five, nine, three, two, zero,
# Nearest to history: list, period, geography, binge, texts, instead, jars, jewish,
# Nearest to united: bletchley, stanislavski, same, reversing, kingman, poverty, catamarans, ultimate,
# Nearest to been: become, be, were, recently, was, already, leds, mansur,
# Nearest to and: or, while, but, than, including, like, through, candide,
# Nearest to or: and, than, the, but, landslide, monocotyledons, ellen, any,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to has: had, have, is, was, since, bloomfield, covering, booting,
# Nearest to s: whose, daime, grilled, spaniard, chanter, fraunhofer, deianira, my,
# Nearest to d: b, w, fujiwara, f, o, kaf, august, r,
# Nearest to state: government, states, city, wang, shipwrecked, atrocities, painted, republic,
# Nearest to new: gotland, particular, brief, bax, grinnell, decisive, prokaryotic, lawrencium,
# Nearest to there: it, they, still, often, she, he, usually, currently,
# Nearest to after: before, during, when, saw, despite, for, while, since,
# Nearest to b: d, f, w, h, r, nm, leiber, n,
# Nearest to UNK: corfu, paranthropus, http, henri, serialised, iter, termination, lexicographic,
# Average loss at step 72000: 3.375653
# Average loss at step 74000: 3.350464
# Average loss at step 76000: 3.320630
# Average loss at step 78000: 3.354243
# Average loss at step 80000: 3.378081
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to history: list, period, geography, proponents, anteater, instead, frustrations, encyclopedia,
# Nearest to united: same, bletchley, kingman, reversing, stanislavski, catamarans, poverty, ultimate,
# Nearest to been: become, be, recently, were, was, already, being, leds,
# Nearest to and: or, while, including, but, than, basotho, intruder, showtime,
# Nearest to or: and, than, while, but, ord, falsifiability, with, laird,
# Nearest to may: can, would, must, will, could, should, might, cannot,
# Nearest to has: had, have, is, was, having, gur, bacterial, since,
# Nearest to s: jurists, coronations, isbn, rx, nacional, betting, iceland, my,
# Nearest to d: b, fujiwara, m, o, f, e, h, l,
# Nearest to state: government, city, states, menai, party, fading, atrocities, cohesion,
# Nearest to new: gotland, brief, particular, prokaryotic, lawrencium, grinnell, bax, magical,
# Nearest to there: it, they, he, still, she, usually, often, currently,
# Nearest to after: before, during, when, despite, while, saw, in, following,
# Nearest to b: d, f, c, r, leiber, k, h, w,
# Nearest to UNK: dysphoria, k, weasels, accented, historicism, williams, pergamon, l,
# Average loss at step 82000: 3.405365
# Average loss at step 84000: 3.410205
# Average loss at step 86000: 3.390820
# Average loss at step 88000: 3.357722
# Average loss at step 90000: 3.365221
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to history: list, period, anteater, jars, geography, demographics, encyclopedia, proponents,
# Nearest to united: same, bletchley, reversing, poverty, kingman, stanislavski, beneath, catamarans,
# Nearest to been: become, be, already, recently, was, being, were, mansur,
# Nearest to and: or, but, while, including, ethnicities, although, though, bryce,
# Nearest to or: and, than, flaminius, while, but, landslide, including, ord,
# Nearest to may: can, would, could, will, must, might, should, cannot,
# Nearest to has: had, have, is, was, having, makes, since, gur,
# Nearest to s: his, whose, coronations, odorless, qualia, deianira, my, her,
# Nearest to d: b, kaf, stewart, freeing, ravages, vigilantes, august, fujiwara,
# Nearest to state: city, government, states, transform, menai, status, atrocities, berkeley,
# Nearest to new: grinnell, facilitates, particular, different, foxes, brief, gotland, modern,
# Nearest to there: it, they, he, she, still, usually, often, now,
# Nearest to after: before, during, when, despite, while, until, coordinators, for,
# Nearest to b: d, f, r, k, h, leiber, c, w,
# Nearest to UNK: henri, formatted, federalists, williams, basset, egoist, schwenkfeld, paranthropus,
# Average loss at step 92000: 3.399926
# Average loss at step 94000: 3.253950
# Average loss at step 96000: 3.361403
# Average loss at step 98000: 3.242675
# Average loss at step 100000: 3.358860
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to history: list, geography, fdr, demographics, abraxas, culture, fleeting, proponents,
# Nearest to united: same, bletchley, poverty, reversing, kingman, southern, beneath, queensland,
# Nearest to been: become, be, recently, already, was, never, mansur, ever,
# Nearest to and: or, but, while, however, including, like, although, when,
# Nearest to or: and, than, dint, ord, socio, while, sanj, fennel,
# Nearest to may: can, could, would, should, must, might, will, cannot,
# Nearest to has: had, have, was, is, since, contains, bloomfield, makes,
# Nearest to s: whose, his, terry, pasted, deficit, agile, sheen, deianira,
# Nearest to d: b, fujiwara, memos, kaf, sacramento, august, c, stateless,
# Nearest to state: city, government, states, status, transform, choice, berkeley, savvy,
# Nearest to new: different, arag, particular, astronomical, brief, carboxylic, gotland, modern,
# Nearest to there: they, it, he, still, usually, often, now, she,
# Nearest to after: before, during, when, despite, while, coordinators, until, although,
# Nearest to b: d, stirner, leiber, blinding, kopp, baptist, saves, motorsport,
# Nearest to UNK: rde, termination, alamein, diogenes, hallucination, pseudopods, paranthropus, altenberg,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
bag_window = 2  # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                                   labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, bag_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()

num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])
# Out:
# Initialized
# Average loss at step 0: 7.824650
# Nearest to nine: dissolution, dietary, tasty, seminole, ordering, ragged, encroached, fewer,
# Nearest to called: flooding, ukrainians, tsr, pos, subgenre, opioids, postmodern, lucasfilm,
# Nearest to will: valpara, pym, kissing, courtesy, refine, superhuman, zagros, engel,
# Nearest to which: intelligibility, belfast, sassanians, ttir, rationing, vicki, combi, encephalitis,
# Nearest to after: transfer, sligo, checksum, defender, traffic, hander, mosque, guiana,
# Nearest to when: clade, immune, comprehensively, ethnicity, between, sheridan, damian, oscillate,
# Nearest to are: laing, secedes, moreno, lautering, brilliant, evolution, pronounces, rejuvenation,
# Nearest to one: kennel, quart, numidia, qq, hoc, accomplishment, golf, weaker,
# Nearest to in: colleague, technetium, aarhus, balmoral, zhukov, assimilated, dieter, pepper,
# Nearest to had: nami, gaines, topics, lithium, cetaceans, copts, zn, comparable,
# Nearest to often: sidonia, levees, frigg, gf, suva, dagger, apostolic, politburo,
# Nearest to from: wenham, mountainous, falkirk, preponderance, curator, recombine, judged, crumble,
# Nearest to war: replies, commence, aelian, ipa, bridged, ashore, sworn, celeste,
# Nearest to than: piron, gris, fascination, shown, wail, youngsters, engels, triode,
# Nearest to years: protracted, aloft, sauropods, imparted, theodoret, gould, magazines, anac,
# Nearest to he: bulls, sandwiches, oyster, evidently, rsa, ennis, nextel, barn,
# Average loss at step 2000: 4.617584
# Average loss at step 4000: 3.922420
# Average loss at step 6000: 3.745139
# Average loss at step 8000: 3.469061
# Average loss at step 10000: 3.526877
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to called: used, named, ukrainians, known, phane, morte, hercule, coloring,
# Nearest to will: would, may, can, should, could, must, might, cannot,
# Nearest to which: that, this, encephalitis, patti, it, downing, weishaupt, equipped,
# Nearest to after: before, during, ben, transfer, condensates, foreground, matches, avraham,
# Nearest to when: if, during, dominatrices, before, ballads, assad, jody, sein,
# Nearest to are: were, is, was, tupelo, include, discontent, polyhedral, paralleling,
# Nearest to one: seven, six, four, eight, concubinage, five, vanadium, nine,
# Nearest to in: on, during, diagonal, where, of, smiling, from, saxophones,
# Nearest to had: has, have, was, having, engaging, sufferings, strangeness, bitmaps,
# Nearest to often: widely, mascots, telco, gf, also, haer, dissenters, commonly,
# Nearest to from: slocum, into, in, cation, worker, clementine, between, crumble,
# Nearest to war: ipa, sings, eudoxia, lion, colors, rows, habitats, defend,
# Nearest to than: or, engels, youngsters, fascination, weathered, benito, influences, holiest,
# Nearest to years: days, beowulf, seas, freikorps, plugged, time, splicing, theodoret,
# Nearest to he: it, she, who, they, hind, falconiformes, callahan, dido,
# Average loss at step 12000: 3.480697
# Average loss at step 14000: 3.441671
# Average loss at step 16000: 3.451657
# Average loss at step 18000: 3.334065
# Average loss at step 20000: 3.316486
# Nearest to nine: eight, seven, zero, six, three, five, four, late,
# Nearest to called: known, finnegan, named, used, considered, pierson, grandstand, garnier,
# Nearest to will: would, may, should, must, could, can, might, to,
# Nearest to which: what, this, that, often, hatfield, anson, sleek, it,
# Nearest to after: before, following, when, biopic, lao, during, steered, bellamy,
# Nearest to when: if, during, before, after, while, because, dominatrices, where,
# Nearest to are: were, is, was, be, discontent, have, include, has,
# Nearest to one: counterfeit, coherence, which, compressibility, nb, two, microcomputers, deprogrammers,
# Nearest to in: during, since, on, until, within, saxophones, bikes, schirra,
# Nearest to had: has, have, having, was, cravings, propellant, intercontinental, blacklist,
# Nearest to often: widely, sometimes, commonly, usually, now, also, still, generally,
# Nearest to from: into, during, without, between, artcyclopedia, swelling, randomized, through,
# Nearest to war: wars, habitats, colors, superiors, emperors, defend, lion, glycolipids,
# Nearest to than: engels, gotland, or, like, piron, holiest, rabbits, bilaterally,
# Nearest to years: days, decades, sultans, year, months, stallone, plugged, times,
# Nearest to he: she, it, they, who, hind, askari, keralite, coronary,
# Average loss at step 22000: 3.344492
# Average loss at step 24000: 3.282503
# Average loss at step 26000: 3.274075
# Average loss at step 28000: 3.274880
# Average loss at step 30000: 3.224200
# Nearest to nine: eight, seven, six, five, zero, four, mid, late,
# Nearest to called: named, used, see, pierson, finnegan, known, referred, considered,
# Nearest to will: would, may, could, should, must, can, might, cannot,
# Nearest to which: that, this, what, where, also, these, whose, often,
# Nearest to after: before, during, for, following, while, when, since, throughout,
# Nearest to when: if, although, because, before, at, where, after, since,
# Nearest to are: were, is, was, recognise, be, discontent, include, have,
# Nearest to one: unscientific, nationwide, regimens, flavouring, souvenirs, fisc, ohio, archie,
# Nearest to in: since, during, within, throughout, including, until, before, from,
# Nearest to had: has, have, having, was, could, saw, would, cravings,
# Nearest to often: sometimes, widely, commonly, frequently, generally, now, usually, also,
# Nearest to from: through, into, while, in, without, among, under, around,
# Nearest to war: habitats, colors, wars, superiors, defend, rows, invasion, emperors,
# Nearest to than: engels, like, but, holiest, influences, gotland, inflated, or,
# Nearest to years: days, decades, year, months, centuries, minutes, kenji, weeks,
# Nearest to he: she, it, they, who, coronary, never, counterpoint, folding,
# Average loss at step 32000: 3.034564
# Average loss at step 34000: 3.215156
# Average loss at step 36000: 3.180350
# Average loss at step 38000: 3.191959
# Average loss at step 40000: 3.166168
# Nearest to nine: eight, six, seven, five, three, two, zero, four,
# Nearest to called: named, used, considered, known, described, garnier, regarded, included,
# Nearest to will: would, could, may, must, should, can, might, cannot,
# Nearest to which: that, this, what, where, often, weishaupt, magnetosphere, jaina,
# Nearest to after: before, when, during, following, assertive, later, so, since,
# Nearest to when: before, if, where, since, then, until, although, during,
# Nearest to are: were, is, discontent, include, was, being, aglaulus, kojiki,
# Nearest to one: coldest, front, unscientific, six, three, pra, powerpuff, resulting,
# Nearest to in: within, during, until, throughout, at, since, through, on,
# Nearest to had: has, have, having, was, could, saw, dara, were,
# Nearest to often: commonly, sometimes, generally, usually, still, widely, frequently, typically,
# Nearest to from: through, into, bukovina, across, clinics, bunyan, slocum, without,
# Nearest to war: wars, habitats, colors, rows, superiors, invasion, pointers, gendered,
# Nearest to than: but, nano, additionally, gotland, among, officiated, while, firemen,
# Nearest to years: days, months, decades, year, centuries, minutes, weeks, times,
# Nearest to he: she, it, they, grasshoppers, kosher, callahan, damn, pantera,
# Average loss at step 42000: 3.207241
# Average loss at step 44000: 3.145168
# Average loss at step 46000: 3.144401
# Average loss at step 48000: 3.063135
# Average loss at step 50000: 3.060185
# Nearest to nine: eight, seven, six, zero, four, five, vol, biopolymers,
# Nearest to called: named, used, considered, sent, garnier, known, found, using,
# Nearest to will: would, should, must, could, may, might, can, cannot,
# Nearest to which: that, this, what, where, actually, kidman, typically, these,
# Nearest to after: before, following, during, assertive, for, when, since, subtree,
# Nearest to when: where, if, while, before, during, because, although, in,
# Nearest to are: were, is, was, discontent, include, have, being, recognise,
# Nearest to one: two, coldest, seven, deprogrammers, unscientific, regimens, leicestershire, domed,
# Nearest to in: during, within, throughout, until, when, despite, on, from,
# Nearest to had: has, have, having, saw, were, was, would, could,
# Nearest to often: commonly, sometimes, usually, widely, generally, frequently, still, typically,
# Nearest to from: through, into, without, in, during, back, throughout, scarecrow,
# Nearest to war: wars, habitats, rows, mitsubishi, gendered, superiors, agent, renowned,
# Nearest to than: or, but, and, like, while, nano, gotland, firemen,
# Nearest to years: days, months, decades, year, centuries, minutes, weeks, times,
# Nearest to he: she, it, they, who, there, ipx, popularization, falconiformes,
# Average loss at step 52000: 3.052924
# Average loss at step 54000: 3.095635
# Average loss at step 56000: 2.938133
# Average loss at step 58000: 3.032604
# Average loss at step 60000: 3.024034
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to called: considered, named, used, referred, termed, sent, known, formed,
# Nearest to will: would, could, should, must, may, can, might, cannot,
# Nearest to which: that, where, this, whose, also, what, albedo, and,
# Nearest to after: before, during, following, despite, when, since, for, at,
# Nearest to when: if, before, though, where, although, because, since, during,
# Nearest to are: were, is, include, was, including, discontent, have, exist,
# Nearest to one: three, two, nucleosynthesis, coldest, reunion, kirtland, appellation, resulting,
# Nearest to in: within, during, throughout, since, outside, despite, until, under,
# Nearest to had: has, have, having, was, gave, saw, could, produces,
# Nearest to often: commonly, usually, sometimes, frequently, generally, widely, typically, still,
# Nearest to from: through, prequels, into, across, britney, via, communes, snows,
# Nearest to war: wars, habitats, mitsubishi, invasion, agent, colony, rows, analyzing,
# Nearest to than: but, or, like, and, firemen, piron, nano, holiest,
# Nearest to years: days, decades, months, centuries, weeks, minutes, year, times,
# Nearest to he: she, it, they, already, brabant, officially, popularization, there,
# Average loss at step 62000: 2.992753
# Average loss at step 64000: 2.943127
# Average loss at step 66000: 2.912301
# Average loss at step 68000: 2.981238
# Average loss at step 70000: 3.010229
# Nearest to nine: eight, seven, zero, december, late, march, f, january,
# Nearest to called: named, considered, used, termed, described, awarded, formed, played,
# Nearest to will: would, could, can, must, should, may, cannot, might,
# Nearest to which: that, where, actually, also, but, when, who, and,
# Nearest to after: before, following, during, when, courtroom, assertive, however, for,
# Nearest to when: if, before, where, although, because, however, while, after,
# Nearest to are: were, is, include, discontent, exist, aglaulus, was, ryukyu,
# Nearest to one: coherence, two, appellation, regimens, est, edom, dek, ric,
# Nearest to in: within, during, since, throughout, on, near, sutter, outside,
# Nearest to had: has, have, having, was, gave, includes, contains, ling,
# Nearest to often: sometimes, commonly, generally, usually, frequently, widely, now, typically,
# Nearest to from: through, across, wenham, into, back, beauharnais, via, sock,
# Nearest to war: wars, habitats, mitsubishi, rows, lion, struggle, superiors, glycolipids,
# Nearest to than: or, but, wail, firemen, nano, tnt, complicated, while,
# Nearest to years: decades, months, days, year, centuries, weeks, minutes, hours,
# Nearest to he: she, it, they, who, glyn, damn, outwards, officially,
# Average loss at step 72000: 2.864957
# Average loss at step 74000: 2.944959
# Average loss at step 76000: 3.002030
# Average loss at step 78000: 2.978710
# Average loss at step 80000: 2.849431
# Nearest to nine: eight, zero, five, four, six, seven, th, two,
# Nearest to called: named, featured, considered, termed, used, played, referred, produced,
# Nearest to will: would, could, might, must, can, should, may, cannot,
# Nearest to which: that, who, where, whom, what, this, also, these,
# Nearest to after: before, during, when, following, within, since, for, assertive,
# Nearest to when: before, where, if, after, because, although, though, then,
# Nearest to are: were, is, include, was, aglaulus, contain, pumpkins, exist,
# Nearest to one: two, vedic, slurs, regimens, appellation, three, unscientific, dek,
# Nearest to in: during, within, throughout, since, on, through, under, outside,
# Nearest to had: has, have, having, was, contains, could, includes, gave,
# Nearest to often: sometimes, commonly, generally, usually, frequently, widely, typically, still,
# Nearest to from: through, across, into, prequels, during, back, bukovina, gohan,
# Nearest to war: wars, habitats, eoka, trigger, invasion, struggle, amaranth, analyzing,
# Nearest to than: or, holiest, typing, firemen, hand, unlike, gotland, but,
# Nearest to years: decades, months, days, centuries, weeks, minutes, year, hours,
# Nearest to he: she, it, they, faramir, asymptomatic, ghazni, negate, rescued,
# Average loss at step 82000: 2.944614
# Average loss at step 84000: 2.898896
# Average loss at step 86000: 2.930908
# Average loss at step 88000: 2.918058
# Average loss at step 90000: 2.833384
# Nearest to nine: eight, seven, six, zero, five, four, late, mid,
# Nearest to called: named, considered, used, known, featured, referred, described, termed,
# Nearest to will: would, must, should, can, could, might, may, cannot,
# Nearest to which: that, where, this, what, who, also, actually, when,
# Nearest to after: before, during, when, following, within, despite, without, until,
# Nearest to when: if, where, because, after, until, unless, however, before,
# Nearest to are: were, is, include, was, aglaulus, ryukyu, have, discontent,
# Nearest to one: two, addition, resulting, seven, unscientific, four, coherence, arrive,
# Nearest to in: during, outside, throughout, within, since, near, on, after,
# Nearest to had: has, have, having, was, produces, includes, provides, contains,
# Nearest to often: usually, sometimes, generally, commonly, frequently, typically, widely, still,
# Nearest to from: into, during, without, across, through, prequels, in, wenham,
# Nearest to war: wars, struggle, habitats, lion, glycolipids, invasion, conflict, encounter,
# Nearest to than: or, firemen, blender, woodwinds, typing, holiest, gotland, unlike,
# Nearest to years: decades, months, days, minutes, centuries, weeks, year, hours,
# Nearest to he: she, it, they, faramir, allegedly, arriving, antiaircraft, jagiello,
# Average loss at step 92000: 2.897447
# Average loss at step 94000: 2.873208
# Average loss at step 96000: 2.559978
# Average loss at step 98000: 2.530853
# Average loss at step 100000: 2.776493
# Nearest to nine: eight, seven, six, five, june, three, four, september,
# Nearest to called: named, considered, referred, used, termed, said, placed, allowed,
# Nearest to will: would, must, should, could, might, can, shall, cannot,
# Nearest to which: that, what, this, where, also, when, who, whom,
# Nearest to after: before, following, for, despite, when, assertive, upon, without,
# Nearest to when: if, although, where, while, though, until, also, before,
# Nearest to are: were, is, was, include, have, contain, enlist, carlisle,
# Nearest to one: unscientific, sizable, resulting, coherence, coldest, regimens, gnaeus, shone,
# Nearest to in: outside, during, within, throughout, at, near, on, into,
# Nearest to had: has, have, having, was, produces, includes, could, contains,
# Nearest to often: usually, sometimes, generally, commonly, frequently, typically, still, widely,
# Nearest to from: into, across, prequels, through, bukovina, without, wenham, toward,
# Nearest to war: wars, struggle, habitats, period, invasion, colony, service, conflict,
# Nearest to than: or, but, triode, inflated, firemen, rabbits, datagrams, officiated,
# Nearest to years: decades, months, minutes, year, days, weeks, hours, centuries,
# Nearest to he: she, it, they, plowing, initially, hanjour, eulemur, europium,

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()


words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)
